# %% [markdown]
# ### Date of Contest: 27-12-2020

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

class SinglyLinkedListNode:
    def __init__(self, node_data):
        self.data = node_data
        self.next = None

class SinglyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    def insert_node(self, node_data):
        node = SinglyLinkedListNode(node_data)

        if not self.head:
            self.head = node
        else:
            self.tail.next = node

        self.tail = node

def print_singly_linked_list(node, sep, fptr):
    while node:
        fptr.write(str(node.data))

        node = node.next

        if node:
            fptr.write(sep)

#
# Complete the 'findLinkedList' function below.
#
# The function is expected to return a LONG_INTEGER_SINGLY_LINKED_LIST.
# The function accepts following parameters:
#  1. LONG_INTEGER_SINGLY_LINKED_LIST head
#  2. INTEGER k
#

#
# For your reference:
#
# SinglyLinkedListNode:
#     long data
#     SinglyLinkedListNode next
#
#

def findLinkedList(head, k):
    # Write your code here
    if k == 1:
        return head
    n = 0
    temp = head
    while temp:
        n += 1
        temp = temp.next
    if k == 2:
        pre = head
        ptr = pre.next
        post = ptr.next
        l = 0
        while pre.next and n - l >= 2:
            l += 2
            conn = pre
            ptr.next = pre
            if conn == head:
                head = ptr
            if post:
                pre = post
                ptr = post.next
                if ptr:
                    post = ptr.next
                conn.next = ptr
            else:
                pre.next = None
        if l < n:
            conn.next = pre
        return head
            
    pre = head
    ptr = pre.next
    post = ptr.next
    conn = None
    l = 0
    while post and n - l >= k:
        l += k
        i = 0
        next_conn = pre
        while i < k - 2:
            ptr.next = pre
            pre = ptr
            ptr = post
            post = post.next
            i += 1
        ptr.next = pre
        if conn:
            conn.next = ptr
        else:
            head = ptr
        conn = next_conn
        pre = post
        if post:
            ptr = post.next
            post = ptr.next
        else:
            next_conn.next = None
    if k < n:
        next_conn.next = pre
    return head

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    l_count = int(input().strip())

    l = SinglyLinkedList()

    for _ in range(l_count):
        l_item = int(input().strip())
        l.insert_node(l_item)

    k = int(input().strip())

    result = findLinkedList(l.head, k)

    print_singly_linked_list(result, ' ', fptr)
    fptr.write('\n')

    fptr.close()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-8482998a6553> in <module>
#     118
#     119 if __name__ == '__main__':
# --> 120     fptr = open(os.environ['OUTPUT_PATH'], 'w')
#     121
#     122     l_count = int(input().strip())
#
# c:\users\anjani\appdata\local\programs\python\python36\lib\os.py in __getitem__(self, key)
#     667         except KeyError:
#     668             # raise KeyError with the original key value
# --> 669             raise KeyError(key) from None
#     670         return self.decodevalue(value)
#     671
#
# KeyError: 'OUTPUT_PATH'

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

class SinglyLinkedListNode:
    def __init__(self, node_data):
        self.data = node_data
        self.next = None

class SinglyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    def insert_node(self, node_data):
        node = SinglyLinkedListNode(node_data)

        if not self.head:
            self.head = node
        else:
            self.tail.next = node

        self.tail = node

def print_singly_linked_list(node, sep, fptr):
    while node:
        fptr.write(str(node.data))

        node = node.next

        if node:
            fptr.write(sep)

#
# Complete the 'rearrangeList' function below.
#
# The function is expected to return a LONG_INTEGER_SINGLY_LINKED_LIST.
# The function accepts LONG_INTEGER_SINGLY_LINKED_LIST head as parameter.
#

#
# For your reference:
#
# SinglyLinkedListNode:
#     long data
#     SinglyLinkedListNode next
#
#

def rearrangeList(head):
    # Write your code here

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    l_count = int(input().strip())

    l = SinglyLinkedList()

    for _ in range(l_count):
        l_item = int(input().strip())
        l.insert_node(l_item)

    result = rearrangeList(l.head)

    print_singly_linked_list(result, ' ', fptr)
    fptr.write('\n')

    fptr.close()
